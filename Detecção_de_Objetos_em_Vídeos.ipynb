# %% [markdown]
# # **Detecção de Objetos em Vídeos com YOLOv8**

# %% [markdown]
# ### **Instalação da biblioteca Ultralytics**

# %%
# !pip install ultralytics==8.0.0

# %%
from IPython.display import Image
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### **Detecção de Objetos em Vídeos**

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/VID_20230621_143501.mp4'
# Out:
# 2023-09-17 02:00:48.709680: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-17 02:00:49.663851: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
# 100% 21.5M/21.5M [00:00<00:00, 150MB/s]
#
# Fusing layers...
# YOLOv8s summary: 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
# video 1/1 (1/414) /content/VID_20230621_143501.mp4: 384x640 2 persons, 5 chairs, 63.2ms
# video 1/1 (2/414) /content/VID_20230621_143501.mp4: 384x640 2 persons, 1 skis, 5 chairs, 11.8ms
# video 1/1 (3/414) /content/VID_20230621_143501.mp4: 384x640 2 persons, 4 chairs, 11.3ms
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Caminho - Vídeo inicial:
save_path = '/content/runs/detect/predict/VID_20230621_143501.mp4'

# Caminho - Vídeo comprimido:
compressed_path = '/content/result_compressed.mp4'

os.system(f'ffmpeg -i {save_path} -vcodec libx264 {compressed_path}')

# Vídeo
mp4 = open(compressed_path, 'rb').read()
data_url = 'data:video/mp4;base64,' + b64encode(mp4).decode()
HTML("""
<video width=1000 controls>
    <source src='%s' type='video/mp4'>
</video>
""" % data_url)
